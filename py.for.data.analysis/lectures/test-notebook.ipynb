# %% [markdown]
# # Some title
#
# ## Subtitle here

# %%
pwd
# Out:
# '/home/andrei/Work/personal/study/py.for.data.analysis'

# %%
class Person:
    def __init__(self, first_name: str, last_name: str):
        self.first_name = first_name
        self.last_name = last_name
    
    def __repr__(self):
        return f"Person({self.first_name}, {self.last_name})"
        
p = Person("Andrei", "Fecioru")
print(p)

print(vars(p))
# Out:
# Person(Andrei, Fecioru)
# {'first_name': 'Andrei', 'last_name': 'Fecioru'}

# %%
import numpy as np

print(np.random.randint(10))

print(f"Some random no.: {np.random.randn()}")
# Out:
# 4
# Some random no.: -0.4491169945684918

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

plt.plot(np.random.randn(100))

# %%
t = (1, 2, 3, 4, 2, 5, 6)
t.count(2)
# Out:
# 2

# %%
fig = plt.figure()
axes1 = fig.add_axes([.1, .1, .8, .8])

# %%
x = np.linspace(0, 100, 101)
y = x ** 2

# %%
fig = plt.figure()

axes1 = fig.add_axes([0, 0, .8, .95])
axes1.set_xlabel("X values")
axes1.set_ylabel("Y values")
axes1.set_title("Linear function")

axes2 = fig.add_axes([1.1, 0, .8, .95])
axes2.set_xlabel("X values")
axes2.set_ylabel("Y values")
axes2.set_title("Non-linear function")

axes1.plot(x, x)
axes2.plot(x, y)
