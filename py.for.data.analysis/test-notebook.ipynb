# %% [markdown]
# # Some title
#
# ## Subtitle here

# %%
import numpy as np

print(np.random.randint(10))

print("Some random no.: {0}".format(np.random.randn()))
# Out:
# 4
# Some random no.: -0.7647674935382905

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.plot(np.random.randn(100))

# %%
t = (1, 2, 3, 4, 2, 5, 6)
t.count(2)
# Out:
# 2
